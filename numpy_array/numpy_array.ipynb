# %%
#numpy array=>

# %%
import numpy as np

# %%
l=[10,20,30,40,50]
ar=np.array(l)

# %%
#basic attributes on array
size
shape
ndim

# %%
ar.size
# Out:
# 5

# %%
ar.shape
# Out:
# (5,)

# %%
ar.ndim
# Out:
# 1

# %%
ar.dtype    #it contain homogenous data only
# Out:
# dtype('int64')

# %%
#create 2 diamention array
l1=[[11,12,13],[14,15,16]]
ar2=np.array(l1)

# %%
ar2
# Out:
# array([[11, 12, 13],
#        [14, 15, 16]])

# %%
#3d array
l3=[[[12,13],[12,13]],[[14,15],[12,13]]]
ar3=np.array(l3)

# %%
ar3.shape
# Out:
# (2, 2, 2)

# %%
ar2[:,0]
# Out:
# array([11, 14])

# %%
import random
a=list(range(10,1,-1))

# %%
a
# Out:
# [10, 9, 8, 7, 6, 5, 4, 3, 2]
